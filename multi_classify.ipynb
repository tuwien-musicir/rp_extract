# %%
import numpy as np
import pandas as pd
from rp_feature_io import load_or_analyze_features, concatenate_features, sorted_feature_subset
from classes_io import *
from rp_classify import standardize, train_model, cross_validate, classify, save_model

# %%
# READ FEATURES

#input_path = 'features/zicotest3'
#input_path = 'features/new_mood_6Xcut'  # pure mood assignments
#input_path = 'features/zico+new_mood'
#input_path = 'features/test_thursday'
input_path = 'features/zico+new_mood+thursday_cut'

ids, feat = load_or_analyze_features(input_path)

# NOTE: Feature files contain audio file names WITH extension. To match with CSV we do:
ids = strip_filenames(ids) # in feature data
# Out:
# Read: rp:	327 vectors 1440 dimensions (excl. id)
# Read: ssd:	327 vectors 168 dimensions (excl. id)
# Read: rh:	327 vectors 60 dimensions (excl. id)

# %%
# READ CLASS DATA

#filename = '../Desktop/annotations/analyse_sample_sep_moods_only_edited.csv'
#filename = '../Desktop/annotations/new mood special.csv'
#filename = '../Desktop/annotations/zico+new_mood.csv'
#filename = '../Desktop/annotations/test_thursday.csv'
filename = '../Desktop/annotations/zico+new_mood+thursday_cut.csv'

# we use pandas to import CSV as pandas dataframe,
# because it handles quoted filenames (containing ,) well (by contrast to other CSV readers)
dataframe = pd.read_csv(filename, sep='\t', index_col=0) 

# NOTE: CSV file is supposed to have file names without extension. otherwise do:
#dataframe.index = strip_filenames(dataframe.index) # in class data

# get categories from the header
categories = dataframe.columns.values.tolist()
n_cat = dataframe.shape[1]

# for new mood special we have X/2 entries which mean like the mood is half present
# we can treat it in two ways:
dataframe.replace('X/2','x', inplace=True)  # consider as fully valid mood (= 100%)
#dataframe.replace('X/2',np.nan, inplace=True)  # ignore it 

# fill empty cells with a n for NO
dataframe.fillna('n', inplace=True)

# %%
for c in categories:
    print c,
# Out:
# fluid saccadé lyric chaotic quiet water air wood ground metal fire

# %%
dataframe
# Out:
#                                          fluid saccadé lyric chaotic quiet  \
# nom
# 01 - Erykah Badu - No More Trouble           x       n     n       n     n
# 01 44 Blues                                  n       n     x       n     n
# 01 A Foggy Day                               x       n     x       n     n
# 01 AAMosambiquetravellplan                   n       x     n       n     n
# 01 Animus Vox                                n       x     n       n     n
# 01 Beep Beep Beep                            n       x     n       x     n
# 01 Chega de Saudade                          x       n     x       n     n
# 01 Chrysalide                                n       n     x       n     n
# 01 GRINNING IN YOUR FACE                     x       n     n       n     n
# 01 Halleluja, I Love Her So                  n       x     x       n     n
# 01 Hear My Train Comin'                      x       n     n       x     n
# 01 Hungarian Polka                           n       n     x       n     n
# 01 Jai Hanuman!                              n       n     x       x     n
# 01 Killing Me Softly With His Song           x       n     n       n     n
# 01 Los Aretes De La Luna                     n       n     x       n     n
# 01 Peace Go With You, Brother                x       n     n       n     n
# 01 Privilege                                 n       x     n       n     n
# 01 Reve 1                                    n       n     n       x     n
# 01 Scream & Shout (feat. Britney Spears)     n       x     n       n     n
# 01 Since I've Been Loving You                x       x     n       n     n
# 01 Space Oddity                              x       x     n       n     n
# 01 Sweet Mercy                               x       n     n       n     n
# 01 Tannhauser Ouverture                      n       n     x       n     n
# 01 Umbrella [Feat. Jay-Z]                    n       x     n       n     n
# 01 We No Who U R                             x       x     n       n     n
# 01A Vivaldi                                  n       n     x       n     n
# 02 (Sittin' On) The Dock Of The Bay          x       n     n       n     n
# 02 Choeur De Femmes - Ujaj                   n       n     n       x     x
# 02 Give 'Em Hell, Kid                        n       x     n       x     n
# 02 Jumpin' Jack Flash                        x       n     n       n     n
# 02 Mika - Relax, Take It Easy                n       x     n       n     n
# 02 Rehab                                     n       x     n       n     n
# 02 Sonnentanz (Oliver Koletzki Remix)        n       n     n       x     n
# 02 Spoken                                    x       n     n       x     n
# 03 Be Like You                               n       n     n       x     n
# 03 Cutting Class                             n       x     n       n     n
# 03 Gangsta                                   n       x     n       n     n
# 03 I Love Paris Too                          n       n     x       n     n
# 03 Italian Shoes                             n       x     n       n     n
# 03 Lucky To Be Me                            n       n     x       n     n
# 03 Suite Meets                               n       n     n       x     n
# 04 - The Computers - Hot Damnocles           n       n     n       x     n
# 04 Chippie                                   n       n     x       n     n
# 04 Je Sais Que Tu Sais                       n       x     n       x     n
# 04 The Touch Of Your Lips                    n       n     x       n     n
# 04B Penny Lane                               n       n     x       n     n
# 05 Devil Take My Soul                        n       n     n       n     n
# 05 Don't Miss Me                             n       x     n       x     n
# 05 I'm Waiting For The Day                   n       n     x       n     n
# 05 La musse                                  x       n     x       n     n
# 05 LA Woman                                  n       x     n       x     n
# 05 The Bottle                                x       x     n       n     n
# 05B The Fool On The Hill                     n       n     x       n     n
# 06 - Mc Lyte - Jammin                        x       x     n       n     n
# 06 - The Computers - Rhythm Revue            n       n     x       x     n
# 06 Cocaine                                   x       x     n       n     n
# 06 Making Plans For Nigel                    n       x     n       n     n
# 06 Powderfinger                              x       x     n       n     n
# 06 Rhythm & Rhyme                            n       x     n       n     n
# 07 - Satisfy My Soul Jah-Jah                 x       n     n       n     n
#                                            ...     ...   ...     ...   ...
#
#                                          water air wood ground metal fire
# nom
# 01 - Erykah Badu - No More Trouble           x   n    n      n     n    n
# 01 44 Blues                                  n   x    n      x     n    n
# 01 A Foggy Day                               x   x    n      n     n    n
# 01 AAMosambiquetravellplan                   n   x    x      x     x    n
# 01 Animus Vox                                n   n    x      x     x    n
# 01 Beep Beep Beep                            n   n    x      x     x    n
# 01 Chega de Saudade                          x   x    n      n     n    n
# 01 Chrysalide                                n   x    x      n     n    n
# 01 GRINNING IN YOUR FACE                     x   n    n      n     n    x
# 01 Halleluja, I Love Her So                  n   x    x      n     n    n
# 01 Hear My Train Comin'                      x   n    n      x     x    n
# 01 Hungarian Polka                           n   x    n      n     n    n
# 01 Jai Hanuman!                              n   x    n      x     n    x
# 01 Killing Me Softly With His Song           x   n    n      n     n    n
# 01 Los Aretes De La Luna                     x   x    n      n     n    n
# 01 Peace Go With You, Brother                x   n    n      n     n    x
# 01 Privilege                                 n   n    x      x     n    n
# 01 Reve 1                                    n   n    n      n     x    n
# 01 Scream & Shout (feat. Britney Spears)     n   x    x      n     n    n
# 01 Since I've Been Loving You                x   n    x      x     n    n
# 01 Space Oddity                              x   n    x      n     x    n
# 01 Sweet Mercy                               x   n    n      n     n    n
# 01 Tannhauser Ouverture                      n   x    n      n     n    n
# 01 Umbrella [Feat. Jay-Z]                    n   n    x      n     n    n
# 01 We No Who U R                             x   n    n      n     x    n
# 01A Vivaldi                                  x   x    n      n     n    n
# 02 (Sittin' On) The Dock Of The Bay          x   n    x      n     n    n
# 02 Choeur De Femmes - Ujaj                   n   n    n      x     n    x
# 02 Give 'Em Hell, Kid                        n   n    x      x     n    n
# 02 Jumpin' Jack Flash                        n   x    n      n     n    n
# 02 Mika - Relax, Take It Easy                x   x    x      n     n    n
# 02 Rehab                                     n   n    x      n     n    n
# 02 Sonnentanz (Oliver Koletzki Remix)        x   n    x      x     n    n
# 02 Spoken                                    x   n    n      x     x    x
# 03 Be Like You                               n   x    x      x     n    n
# 03 Cutting Class                             n   n    x      n     n    n
# 03 Gangsta                                   n   x    x      n     n    n
# 03 I Love Paris Too                          x   x    n      n     n    n
# 03 Italian Shoes                             n   n    x      n     n    n
# 03 Lucky To Be Me                            x   x    n      n     n    n
# 03 Suite Meets                               n   n    n      x     n    n
# 04 - The Computers - Hot Damnocles           n   n    x      x     n    n
# 04 Chippie                                   x   x    n      n     n    n
# 04 Je Sais Que Tu Sais                       n   n    x      x     n    n
# 04 The Touch Of Your Lips                    x   x    n      n     x    n
# 04B Penny Lane                               n   x    n      n     n    n
# 05 Devil Take My Soul                        x   n    x      n     n    n
# 05 Don't Miss Me                             n   n    x      x     n    n
# 05 I'm Waiting For The Day                   x   x    n      n     x    n
# 05 La musse                                  x   x    n      n     n    n
# 05 LA Woman                                  n   n    x      x     n    n
# 05 The Bottle                                x   x    x      n     n    n
# 05B The Fool On The Hill                     n   x    n      n     x    n
# 06 - Mc Lyte - Jammin                        x   n    x      n     n    n
# 06 - The Computers - Rhythm Revue            n   x    x      x     n    n
# 06 Cocaine                                   x   n    x      n     n    n
# 06 Making Plans For Nigel                    n   x    x      n     n    n
# 06 Powderfinger                              x   n    x      n     n    n
# 06 Rhythm & Rhyme                            x   n    x      n     n    n
# 07 - Satisfy My Soul Jah-Jah                 n   x    x      n     n    n
#                                            ... ...  ...    ...   ...  ...
#
# [342 rows x 11 columns]

# %%
# MATCH AUDIO AND CLASS DATA

# build initial class dictionary (for matching and sorting the ids)
keys = dataframe.index # filename
vals = dataframe.ix[:,0].tolist() # values in first column
class_dict = dict(zip(keys,vals))

# retain only a file ids where audio and class filenames (ids) are matching
class_dict_matched = match_and_reduce_class_dict(class_dict, ids, strip_files = False)
# we don't really need that class_dict, just the matched ids
ids_matched = class_dict_matched.keys()
# Out:
# 342 files in class definition file
# 327 files from audio feature analysis
# 325 files matching

# %%
# sorting or not sorting changes the results of cross-validation :-(
ids_matched = sorted(ids_matched)

# %%
# output missing files
print 'in class definition but not in audio files:\n'
d = set(keys) - set(ids_matched)
for f in d: print f
# Out:
# in class definition but not in audio files:
#
# It's My Birthday
# exofavela6
# exofavela5
# sony mix
# move like jagger
# Happy (Official Music Video)-16
# Blurred Lines ft. T.I., Pharrell
# Unsquare dance (114x79)
# Show Yourself _ Tun Ova Riddim _ June 2013
# bourgoisie blues
# Cargo de nuit
# 2-12 I'm Sitting On Top Of The World
# 01 GRINNING IN YOUR FACE
# Can't Hold Us
# 09 What Do I Have To Do T Prove My Love To You
# printemps
# 12 マンモスの行進

# %%
print 'in audio files but not in class definition:\n'
d = set(ids) - set(ids_matched)
for f in d: print f
# Out:
# in audio files but not in class definition:
#
# 04 I Want To Be Happy
# The Walking Dead - Générique Saison 5 [OFFICIEL]

# %%
# create a new reduced dataframe that contains only the matched files (in the matched order)
dataframe_cut = dataframe.ix[ids_matched]

# %%
# check for duplicates
l = list(dataframe_cut.index)
dup = set([x for x in l if l.count(x) > 1])
dataframe.ix[dup]
# Out:
# Empty DataFrame
# Columns: [fluid, saccadé, lyric, chaotic, quiet, water, air, wood, ground, metal, fire]
# Index: []
#
# [0 rows x 11 columns]

# %%
# PREPARE FEATURES

# resort the features same as the new matched dataframe and class subset
#feat_sorted = sorted_feature_subset(feat, ids, class_dict_matched) # BUG?
feat_sorted = sorted_feature_subset(feat, ids, ids_matched)
# debug
fe = feat_sorted['rh']
print fe.shape[0], "files,", fe.shape[1], "feature dimensions"

# select the feature types to use + combine
#feature_types = ('ssd','rh')
#feature_types = ('rp')
#feature_types = ('rp','ssd')
feature_types = ('rp','ssd','rh')
feat_merged = concatenate_features(feat_sorted, feature_types)

# standardize
features, scaler = standardize(feat_merged)

# debug
print len(ids)
print len(class_dict_matched)
print len(set(class_dict_matched.keys()).intersection(ids))
print features.shape[0], "files,", features.shape[1], "feature dimensions"
# Out:
# 325 files, 60 feature dimensions
# 327
# 325
# 325
# 325 files, 1668 feature dimensions

# %%
# CLASSIFICATION LOOP

models = {} # store all models in a dict
labelenc = {} # store all labelencoders in a dict
mean_acc_overall = 0

model_file_stub = "models/model."

# iterate over the columns (= categories)
for col in range(n_cat):

    # get the column for this category
    cat = categories[col]
    print "Class: " + cat + ": \t",
    class_labels = dataframe_cut.ix[:,col].tolist()
    
    # number of positive class labels
    n_examples = sum(c == 'x' for c in class_labels)
    print n_examples, 'files\t',
    
    # convert to numeric classes
    classes_num, labelencoder = classes_to_numeric(class_labels, verbose=False, return_encoder = True)
    
    # train model
    # with_probabilities is needed when we want to output probabilities at test time
    # but it takes much longer (as it does internal cross-validation) and results may also be different 
    model = train_model(features, classes_num, with_probabilities = False, print_accuracy = False)
    
    # store in memory (dict)
    models[cat] = model
    labelenc[cat] = labelencoder
    
    # cross validate accuracy
    acc = cross_validate(model, features, classes_num, folds=10)
    #print "Avg Accuracy (%d folds): %2.2f %% \t (stddev: %2.2f)" % (len(acc), (np.mean(acc)*100), np.std(acc)*100)
    mean_acc = np.mean(acc)
    print "%2.2f %%" %  (mean_acc*100)
    mean_acc_overall += mean_acc
    
    # save model
    save_model(model_file_stub + cat + ".pkl", model, scaler, labelencoder)

mean_acc_overall /= n_cat
print 'OVERALL Mean Accuracy: %2.2f %%' %  (mean_acc_overall*100)
# Out:
# Class: fluid: 	86 files	70.44 %
# Class: saccadé: 	136 files	71.01 %
# Class: lyric: 	90 files	67.70 %
# Class: chaotic: 	75 files	74.83 %
# Class: quiet: 	38 files	92.66 %
# Class: water: 	136 files	63.44 %
# Class: air: 	112 files	65.28 %
# Class: wood: 	132 files	71.63 %
# Class: ground: 	98 files	65.67 %
# Class: metal: 	50 files	73.84 %
# Class: fire: 	47 files	88.62 %
# OVERALL Mean Accuracy: 73.19 %

# %%
# TESTING
#test_path = 'features/test-eau'
#test_path = 'features/test_new_thomas'
#test_path = "features/zicotest3"
#test_path = "features/test_wednesday"
test_path = 'features/thursday_verify'
result_filename = 'output/thursday_verify.csv'
ids_test, feat_test = load_or_analyze_features(test_path)

# SELECT OR CONCATENATE FEATURES
feat_test_merged = concatenate_features(feat_test, feature_types)

# SCALE FEATURES LIKE TRAINING DATA
features_to_classify = scaler.transform(feat_test_merged)

# CLASSIFY (each category separately)

# initialize results dict with empty list so entries are contained that do not have a single positive prediction
results = {}
for f in ids_test:
    results[f] = []

# if a prediction was made for a certain category, add its name to the dict list
for cat in categories:  
    predictions = classify(models[cat], features_to_classify, labelenc[cat])

    for f,p in zip(ids_test,predictions):
        #print f, "\t", p
        if p == 'x':
            if not f in results:
                results[f] = [cat] # create new 1-entry list entry in results dict
            else:
                results[f].append(cat) # append to existing list
# Out:
# Read: rp:	69 vectors 1440 dimensions (excl. id)
# Read:
#  ssd:	69 vectors 168 dimensions (excl. id)
# Read: rh:	69 vectors 60 dimensions (excl. id)

# %%
# print results
print "Input Audio Analysis for Model:", input_path
print "Input Expert Class Annotations:", filename
print "Audio Files to Test:", test_path
print "Output file:", result_filename
print
print "PREDICTIONS:"
for k in results.keys():
    print k, '\t', ", ".join(results.get(k))

# SAVE to output file
fil = open(result_filename,'w')
fil.write("Input Audio Analysis for Model:\t" + input_path + '\n')
fil.write("Feature Types used:\t" + ", ".join(feature_types).upper() + '\n')
fil.write("Input Expert Class Annotations:\t" + filename + '\n')
fil.write("Audio Files to Test:\t" + test_path + '\n')
fil.write("PREDICTIONS:\n\n")
for k in results.keys():
    fil.write(k + '\t' + "\t".join(results.get(k)) + '\n') 
fil.close()
# Out:
# Input Audio Analysis for Model: features/zico+new_mood+thursday_cut
# Input Expert Class Annotations: ../Desktop/annotations/zico+new_mood+thursday_cut.csv
# Audio Files to Test: features/thursday_verify
# Output file: output/thursday_verify.csv
#
# PREDICTIONS:
# 10 Song For Elis [Instrumental].mp3 	fluid, water, metal
# 1 The Trembler.aiff 	water, ground
# 01 From Hell.mp3 	wood
# 1 Let's Go Down.mp3 	water
# 08 Get Lucky (feat. Pharrell Williams).mp3 	fluid, saccadé, air, wood
# missa.aiff 	chaotic, air, ground
# On Health Origami23 Remix.wav 	chaotic, water
# 1-04 Lonely Woman _ Nardis.mp3 	lyric, water, air, metal
# 10 My Friend.mp3 	fluid, lyric, water
# 01 Estampida.mp3 	saccadé, wood, ground
# 08 Nietzschean Love Theme.aif 	saccadé, water, air, wood, ground
# 05 Run Cried The Crawling.mp3 	fluid, quiet, water, fire
# 01 Search And Destroy.mp3 	lyric, air, wood, ground
# 03 Flight.aif 	saccadé, chaotic, water
# 01 Inolvidable.mp3 	water, wood
# 02 Born To Lead.mp3 	saccadé, wood, ground
# 03 Dream Gypsy.aif 	lyric, water, air, metal
# 02 Soulman.mp3 	fluid, saccadé, water, wood
# 1-03 Where We Used To Live.aif 	water, metal
# 08 The Thrill Is Gone.aif 	lyric, quiet, water, air
# 15 I Remember.mp3 	lyric, water, air, metal
# 02 Karmacoma.mp3 	saccadé, chaotic, ground
#  04 D.R album 9.mp3 	fluid, saccadé, lyric, chaotic, water, metal
# 11 The Prisoner.mp3 	fluid, lyric, water
# 01 Las Puertas.mp3 	lyric, water, air
# 01 Motherless Child.mp3 	fluid, saccadé, water, wood
# 2-03 Pulsing Study Of Sine Waves Part Two.aif
# 12 Blue Moon.mp3 	quiet, water, fire
# 01 Doubts.mp3 	lyric
# 06 Light Upon Light.aif 	quiet, fire
# 03 I Love Paris Too.aif 	lyric, water, air
# 3 Piste audio.mp3 	lyric, water, metal
# 02 Gymnopédie No.2.mp3 	lyric, quiet, water, air, fire
# 01 The Fallen.mp3 	saccadé, wood
# 02 Entangled.mp3 	lyric, ground, fire
# 01 you think i ain't worth a dollar but i feel like a millionaire.mp3
# 08 I Feel Like a Child.mp3 	water, wood, ground
# Philip Glass - 1000 Airplanes on the Roof - 03 - Girlfriend.mp3 	lyric, quiet, air, ground, fire
# 01 Booty Bumpin'.mp3 	saccadé, lyric, water, wood, ground, metal
# 01 Ballad I.mp3 	fluid, lyric, quiet, water, air, metal
# 01 Rehab feat Jay-Z.mp3 	saccadé, lyric, water, air, metal
# 04 Romance.mp3 	fluid, water
# 05 Kathy's Waltz.mp3
# Scatta Head (Zenzile Dub Mix).mp3 	fluid, saccadé, wood
# 01 We Will Rock You (Ruined By Rick Rubin).mp3 	saccadé, water, wood
# 04 Romano Hip Hop.mp3 	saccadé, chaotic, wood
# 03 Turning.mp3 	lyric, air
# 1-02 Tristesse (for Paul Motian).mp3 	lyric, water, air, metal
# 01 Tortured Soul.mp3 	saccadé, lyric, air
# 03 Do the Boomerang.mp3 	fluid, saccadé, wood, metal
# 01 Sacrè _The Wine Ode Suite_.mp3 	lyric, quiet, fire
# 01 Peace Go With You, Brother.mp3 	fluid, water, fire
# 06 Bending New Corners.aif 	saccadé, water, air, wood
# 10 Scene 4_ Hymn.mp3 	lyric, chaotic, air, ground
# 03 Good Rockin' Tonight.mp3 	chaotic, water, air, ground, metal
# 3 Water Girl.mp3 	fluid, lyric, metal
# 02 09-15-00, Pt. 2.mp3 	chaotic, quiet, air, ground
# 01 dillinger mahiuanebrain 1A.mp3 	lyric, water, air
# 05 Le Mendiant De L'Amour.mp3 	fluid, chaotic, ground
# 03 Eternal Woman.mp3 	fluid, saccadé, water, air
# 02 J'ai Vu Un Ange_ I Have Seen An Angel.mp3 	lyric, water, air
# 08 Rupture.mp3 	saccadé, chaotic, wood, ground
# 03 DESDEMONA.mp3 	chaotic, water, air
# 03 Soft Black Stars.mp3 	water, air, fire
# 05 The Bottle.mp3 	fluid, saccadé, water, air, wood
# 01 Taniotoshi.mp3 	fluid, saccadé, water, wood
# come together.mp3 	lyric, air, wood
# 02 L'uzure.mp3 	saccadé, chaotic, water, wood, metal
# 02 Pusherman.mp3

# %%
# TEST WITH PROBABILITIES

cat = categories[0]
print cat

model = models[cat]
print model.classes_
print labelenc[cat].inverse_transform(model.classes_)
pred = model.predict(features_to_classify)
prob = model.predict_proba(features_to_classify)
dec = model.decision_function(features_to_classify)

for c, p, d in zip(pred,prob,dec):
    print c, p, d

# NOT UNDERSTANDABLE
#fluid
#[0 1]
#['n' 'x']
#1 [ 0.60997072  0.39002928] 0.777435842855
#0 [ 0.76297632  0.23702368] -0.831269278351
#1 [ 0.56023258  0.43976742] 1.24380788124
#1 [ 0.59362058  0.40637942] 0.933793985289
#0 [ 0.77118897  0.22881103] -0.934217910963
# Out:
# fluid
# [0 1]
# ['n' 'x']
# 1 [ 0.60997072  0.39002928] 0.777435842855
# 0 [ 0.76297632  0.23702368] -0.831269278351
# 1 [ 0.56023258  0.43976742] 1.24380788124
# 1 [ 0.59362058  0.40637942] 0.933793985289
# 0 [ 0.77118897  0.22881103] -0.934217910963
# 0 [ 0.81710623  0.18289377] -1.56536145762
# 1 [ 0.62804922  0.37195078] 0.599950849521
# 0 [ 0.72453793  0.27546207] -0.378934717323
# 0 [ 0.73162446  0.26837554] -0.459098559873
# 1 [ 0.53875344  0.46124656] 1.43882272062
# 0 [ 0.76062336  0.23937664] -0.802230326528
# 0 [ 0.7763331  0.2236669] -1.00002887449
# 0 [ 0.77633652  0.22366348] -1.00007303826
# 0 [ 0.82269435  0.17730565] -1.65011663498
# 1 [ 0.64956628  0.35043372] 0.381208952043
# 0 [ 0.75783116  0.24216884] -0.768023117774
# 1 [ 0.64826474  0.35173526] 0.394695420357
# 0 [ 0.88252529  0.11747471] -2.72921228643
# 1 [ 0.5353889  0.4646111] 1.46917289404
# 0 [ 0.70763976  0.29236024] -0.192754905371
# 1 [ 0.60164681  0.39835319] 0.85748535189
# 0 [ 0.83718879  0.16281121] -1.8802189222
# 1 [ 0.66489951  0.33510049] 0.219659382057
# 1 [ 0.64064927  0.35935073] 0.472929744487
# 1 [ 0.58784153  0.41215847] 0.988251319102
# 0 [ 0.74820154  0.25179846] -0.652058662781
# 1 [ 0.40793614  0.59206386] 2.61526289614
# 1 [ 0.17283892  0.82716108] 5.29185068972
# 0 [ 0.83520366  0.16479634] -1.84776213318
# 0 [ 0.72426618  0.27573382] -0.375886391751
# 1 [ 0.56863433  0.43136567] 1.16674032047
# 1 [ 0.61604916  0.38395084] 0.718342704933

# %%
# print results
print "PREDICTIONS:"
for k in results.keys():
    print k, '\t', 
    for c in results.get(k):
        print c + ',',
    print
# Out:
# PREDICTIONS:
# PYT.mp3 	fluid, saccadé, wood,
# 02 Africa Kingdom.mp3 	fluid, saccadé, water, wood,
# 01 the creator has a master plan.mp3 	fluid, water, metal,
# 1-05 Afro Blue.aif 	lyric, chaotic, water, ground, metal,
# Shining Star.mp3 	saccadé, wood, metal,
# I_d Like To Hitch A Ride With Santa Claus.mp3 	fluid, lyric, water, air,
# 1-16 Rock-A-Bye Your Baby With A Dixie Melody.wav 	fluid, lyric, water, air, wood,
# 2-04 Try A Little Tenderness.wav 	fluid, quiet, water, fire,
# 1-01 Born Slippy .NUXX [Short].mp3 	chaotic, quiet, water, metal,
# 06 Ich Will Dir Mein Herze Schenken, Extrait De La Passion Selon Saint Matthieu, BWV 244.aif 	lyric, quiet, air, fire,
# 03 Oh Happy Day.mp3 	ground,
# 11 Le Bien, Le Mal.mp3 	fluid, saccadé, water, wood,
# 14 African Motion.mp3 	quiet, metal, fire,
# 1-05 I Shot The Sheriff.mp3 	fluid, saccadé, water, wood,
# 07 Little Girl Blue.aif 	fluid, water,
# 01 Reve 1.aif 	chaotic, metal,
# 01 My Foolish Heart.mp3 	water, air,
# 15 Samba Do Suenho.mp3 	lyric, air, fire,
# 05 Movement Of The People.mp3 	fluid, saccadé, chaotic, wood, ground,
# 03 Street Scene (4 Shazz).mp3 	saccadé, water, air, wood, metal,
# 01 Ordinary Joe (Live).aif 	lyric, air,
# 07 Baba.mp3 	fluid, lyric, water, air,
# 1-11 Black Dog.mp3 	saccadé, chaotic, wood, ground,
# 2-15 Just For A Thrill.wav 	fluid, water, air, ground,
# Give It Up Turn It Loose.mp3 	fluid, saccadé, water, wood,
# 01 Smooth Operator.mp3 	fluid, water, air,
# 06 Feeling Good.wav 	fluid, water,
# 03 Song Of Space.mp3 	water,
# 1-05 Definition Of A Dog.aif 	lyric, water, air,
# 04 Twelve Tone Tune.mp3 	water,
# 06 Jazz It At Home.mp3 	chaotic, wood, ground,
# 04 Red Star.aif 	fluid, saccadé, water, air, metal,

# %%
def sorted_feature_subset(features, ids_orig, ids_select):
    '''
    selects a (sorted) subset of the original features array
    features: a feature dictionary, containing multiple np.arrays one for each feature type ('rh', 'ssd', etc.)
    ids_orig: original labels/ids for the featurs, MUST be same length AND order as feature arrays
    ids_select: set of ids in different order or subset of ids to be selected from original feature arrays
    returns: sorted subset of the original features array
    '''
    new_feat = {}
    for e in features.keys():
        dataframe = pd.DataFrame(features[e], index = ids_orig)
        new_feat[e] = dataframe.ix[ids_select].values
    return new_feat

# %%
import numpy as np

def concatenate_features(feat, feature_types = ('ssd', 'rh')):
    ''' concatenate features vectors of various feature types together
    (all entries in feature dictionary  must have same number of instances, but can have different dimensions
    feat: feature dictionary, containing np.arrays for various feature types (named 'ssd', 'rh', etc.)
    feature_types: tuple of strings with the names of feature types to concatenate (1 entry tuple or string is 
        allowed, will return this feature type only, without concatenation)
    '''
    # in case only 1 feature type instad of tuple was passed
    if isinstance(feature_types, str):
        new_feat = feat[feature_types]
    else:
        # take the first feature type
        new_feat = feat[feature_types[0]]
        # and iteratively horizontally stack the remaining feature types
        for e in feature_types[1:]:
            new_feat = np.hstack((new_feat, feat[e]))
    return new_feat
